# %%
import kagglehub
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# Download latest version
path = kagglehub.dataset_download("atharvasoundankar/futuristic-smart-city-citizen-activity-dataset")

print("Path to dataset files:", path)

DATA_DIR = Path("..") / "data"
file_path = DATA_DIR / "smart_city_citizen_activity.csv"

from kagglehub import KaggleDatasetAdapter

file_path = "smart_city_citizen_activity.csv"

df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "atharvasoundankar/futuristic-smart-city-citizen-activity-dataset",
  file_path,)
# Out:
# Path to dataset files: /Users/tiana/.cache/kagglehub/datasets/atharvasoundankar/futuristic-smart-city-citizen-activity-dataset/versions/1
# /var/folders/fm/zzjr3l5d7nl5vdp9q79tzwvh0000gn/T/ipykernel_4728/500265655.py:19: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(

# %%
df["Gender"].unique()
df["Gender"] = df["Gender"].str.strip().str.title()

gender_map = {
    "Male": 0,
    "Female": 1,
    "Other": 2
}

df["Gender"] = df["Gender"].map(gender_map)

# %%
df["Gender"].unique()
# Out:
# array([1, 0, 2])

# %%
df["Mode_of_Transport"] = df["Mode_of_Transport"].replace({
    "Bike": "Bicycle"
})

# %%
df["Mode_of_Transport"] = df["Mode_of_Transport"].str.strip().str.lower()

transport_map = {
    "walking": 0,
    "bicycle": 1,
    "car": 2,
    "ev": 3,
    "public transport": 4
}

df["Mode_of_Transport"] = df["Mode_of_Transport"].map(transport_map)

# %%
df["Mode_of_Transport"].unique()
# Out:
# array([0, 1, 2, 3, 4])

# %%
print("Shape:", df.shape)
df.head()
# Out:
# Shape: (1000, 15)
#    Citizen_ID  Age  Gender  Mode_of_Transport  Work_Hours  Shopping_Hours  \
# 0        1001   56       1                  0           5               2
# 1        1002   69       0                  1           0               2
# 2        1003   46       0                  1           0               4
# 3        1004   32       0                  2           7               2
# 4        1005   60       0                  0           3               3
#
#    Entertainment_Hours  Home_Energy_Consumption_kWh  Charging_Station_Usage  \
# 0                    0                         5.32                       0
# 1                    2                         2.19                       0
# 2                    0                         4.68                       0
# 3                    3                         3.42                       0
# 4                    1                         2.79                       0
#
#    Carbon_Footprint_kgCO2  Steps_Walked  Calories_Burned  Sleep_Hours  \
# 0                   44.70         15635              975          9.2
# 1                   92.39          1671              455          8.1
# 2                   78.57          1777              324          4.7
# 3                   55.46          4022              537          4.9
# 4                   98.95         19244             1414          6.6
#
#    Social_Media_Hours  Public_Events_Hours
# 0                 5.8                  0.5
# 1                 5.5                  1.9
# 2                 3.8                  2.8
# 3                 3.5                  0.5
# 4                 2.2                  0.5

# %%
df.info(), df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Citizen_ID                   1000 non-null   int64
#  1   Age                          1000 non-null   int64
#  2   Gender                       1000 non-null   int64
#  3   Mode_of_Transport            1000 non-null   int64
#  4   Work_Hours                   1000 non-null   int64
#  5   Shopping_Hours               1000 non-null   int64
#  6   Entertainment_Hours          1000 non-null   int64
#  7   Home_Energy_Consumption_kWh  1000 non-null   float64
#  8   Charging_Station_Usage       1000 non-null   int64
#  9   Carbon_Footprint_kgCO2       1000 non-null   float64
#  10  Steps_Walked                 1000 non-null   int64
#  11  Calories_Burned              1000 non-null   int64
#  12  Sleep_Hours                  1000 non-null   float64
#  13  Social_Media_Hours           1000 non-null   float64
#  14  Public_Events_Hours          1000 non-null   float64
# dtypes: float64(5), int64(10)
# memory usage: 117.3 KB
# (None,
#          Citizen_ID         Age       Gender  Mode_of_Transport   Work_Hours  \
#  count  1000.000000  1000.00000  1000.000000        1000.000000  1000.000000
#  mean   1500.500000    43.81900     0.566000           1.754000     4.397000
#  std     288.819436    14.99103     0.572688           1.340627     2.870127
#  min    1001.000000    18.00000     0.000000           0.000000     0.000000
#  25%    1250.750000    31.00000     0.000000           1.000000     2.000000
#  50%    1500.500000    44.00000     1.000000           1.000000     4.000000
#  75%    1750.250000    56.00000     1.000000           3.000000     7.000000
#  max    2000.000000    69.00000     2.000000           4.000000     9.000000
#
#         Shopping_Hours  Entertainment_Hours  Home_Energy_Consumption_kWh  \
#  count     1000.000000          1000.000000                  1000.000000
#  mean         2.024000             1.532000                     5.996900
#  std          1.421071             1.102811                     2.302009
#  min          0.000000             0.000000                     2.000000
#  25%          1.000000             1.000000                     4.050000
#  50%          2.000000             2.000000                     5.870000
#  75%          3.000000             2.250000                     8.010000
#  max          4.000000             3.000000                     9.990000
#
#         Charging_Station_Usage  Carbon_Footprint_kgCO2  Steps_Walked  \
#  count              1000.00000             1000.000000   1000.000000
#  mean                  0.29400               54.416840  10514.961000
#  std                   0.45582               26.062576   5588.931531
#  min                   0.00000               10.020000   1011.000000
#  25%                   0.00000               31.717500   5679.500000
#  50%                   0.00000               53.665000  10448.500000
#  75%                   1.00000               77.865000  15377.500000
#  max                   1.00000               99.930000  19972.000000
#
#         Calories_Burned  Sleep_Hours  Social_Media_Hours  Public_Events_Hours
#  count       1000.00000  1000.000000         1000.000000          1000.000000
#  mean         818.61300     6.987000            3.007500             1.503600
#  std          302.49261     1.710923            1.706249             0.874226
#  min          171.00000     4.000000            0.000000             0.000000
#  25%          581.00000     5.500000            1.600000             0.800000
#  50%          805.00000     7.000000            3.000000             1.500000
#  75%         1070.00000     8.400000            4.400000             2.300000
#  max         1447.00000    10.000000            6.000000             3.000000  )
